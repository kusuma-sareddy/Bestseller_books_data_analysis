# %%
import pandas as pd

# %%
df=pd.read_csv("book_details_category.csv")

# %%
df
# Out:
#                                              book name  \
# 0                             Lets Crack SSB Interview
# 1    My First Library: Boxset of 10 Board Books for...
# 2    Fruits - My First Early Learning Wall Chart: F...
# 3    My First Book of Patterns: Pencil Control: Pat...
# 4    Colouring Books Boxset: Pack of 12 Copy Colour...
# ..                                                 ...
# 396  Illustrated Stories of Akbar and Birbal: Class...
# 397  The Tale of a Naughty Prank: A Puffin Chapter ...
# 398  Majestic Animals: Colouring Books for Adults w...
# 399      Creative Coloring Mandala for Kids(Paperback)
# 400  MTG National Science Olympiad (NSO) Workbook f...
#
#                                                 Author  \
# 0                                             SSBCrack
# 1    Wonder House Books Editorial(Author),  Wonder ...
# 2                                   Wonder House Books
# 3    Wonder House Books Editorial(Author),  Wonder ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   book name    389 non-null    object
#  1   Author       369 non-null    object
#  2   category     401 non-null    object
#  3   Released     381 non-null    object
#  4   Rating       237 non-null    float64
#  5   MRP          401 non-null    object
#  6   Save_upto    333 non-null    object
#  7   discount     333 non-null    object
#  8   No of pages  380 non-null    float64
#  9   returnable   225 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 31.5+ KB

# %%
# Summary statistics for numerical columns
df.describe()
# Out:
#            Rating  No of pages
# count  237.000000   380.000000
# mean     4.509283   383.034211
# std      0.287299   535.125198
# min      3.200000     1.000000
# 25%      4.400000   120.000000
# 50%      4.500000   246.000000
# 75%      4.700000   421.000000
# max      4.900000  5264.000000

# %%
df.describe(include='object')
# Out:
#                                          book name              Author  \
# count                                          389                 369
# unique                                         386                 271
# top     Power of Your Subconscious Mind(Paperback)  Wonder House Books
# freq                                             3                  25
#
#        category     Released   MRP Save_upto discount returnable
# count       401          381   401       333      333        225
# unique       19          286   166       129       38          2
# top     General  28 Mar 2024  ₹299       ₹60      40%          Y
# freq        134            7    32        45       62        204

# %% [markdown]
# ### Checking if there are any null values

# %%
df.isnull().sum()
# Out:
# book name       12
# Author          32
# category         0
# Released        20
# Rating         164
# MRP              0
# Save_upto       68
# discount        68
# No of pages     21
# returnable     176
# dtype: int64

# %% [markdown]
# ### Returnable

# %%
df['returnable']
# Out:
# 0      NaN
# 1        Y
# 2      NaN
# 3        Y
# 4        Y
#       ...
# 396      Y
# 397    NaN
# 398      Y
# 399      Y
# 400    NaN
# Name: returnable, Length: 401, dtype: object

# %%
df['returnable'].values
# Out:
# array([nan, 'Y', nan, 'Y', 'Y', nan, 'Y', 'Y', nan, nan, nan, nan, 'Y',
#        'Y', nan, 'Y', 'Y', nan, 'Y', nan, 'Y', 'Y', nan, nan, nan, 'Y',
#        'Y', 'Y', 'N', 'Y', nan, 'Y', nan, nan, nan, 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', nan, nan, 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        nan, nan, 'Y', nan, nan, 'Y', 'Y', nan, 'Y', nan, 'Y', 'Y', 'Y',
#        nan, nan, nan, 'Y', nan, 'Y', nan, 'Y', nan, nan, 'Y', nan, 'Y',
#        nan, nan, 'Y', 'Y', 'Y', 'Y', nan, nan, nan, 'Y', nan, 'N', nan,
#        nan, 'Y', 'Y', nan, nan, nan, nan, 'Y', nan, 'Y', 'Y', 'Y', 'Y',
#        nan, 'Y', 'Y', 'Y', nan, nan, 'Y', 'Y', 'Y', 'N', nan, nan, nan,
#        'Y', 'Y', 'Y', 'Y', nan, 'Y', 'Y', 'Y', nan, 'Y', 'Y', nan, nan,
#        'Y', 'Y', 'Y', nan, 'Y', 'Y', 'Y', 'Y', 'Y', nan, 'Y', nan, nan,
#        'N', 'Y', 'Y', nan, 'Y', nan, 'Y', 'Y', 'Y', nan, 'Y', 'Y', 'Y',
#        nan, 'Y', 'Y', nan, nan, nan, nan, 'Y', nan, nan, nan, nan, 'Y',
# ...

# %%
df['returnable'].describe()
# Out:
# count     225
# unique      2
# top         Y
# freq      204
# Name: returnable, dtype: object

# %%
#replacing NAN values in returnable to Unknow
df['returnable'] = df['returnable'].fillna('Unknown')

# %%
df['returnable'].value_counts()
# Out:
# Y          204
# Unknown    176
# N           21
# Name: returnable, dtype: int64

# %% [markdown]
# # MRP

# %%
#MRP
df['MRP']
# Out:
# 0      ₹465
# 1      ₹749
# 2      ₹199
# 3      ₹149
# 4      ₹629
#        ...
# 396    ₹299
# 397    ₹199
# 398    ₹299
# 399    ₹149
# 400    ₹139
# Name: MRP, Length: 401, dtype: object

# %%
df['MRP'].values
# Out:
# array(['₹465', '₹749', '₹199', '₹149', '₹629', '₹699', '₹399', '₹299',
#        '₹1,090', '₹350', '₹250', '₹799', '₹949', '₹349', '₹1,558', '₹275',
#        '₹499', '₹396', '₹199', '₹258', '₹275', '₹990', '₹1,399', '₹399',
#        '₹250', '₹349', '₹1,499', '₹250', '₹125', '₹299', '₹403', '₹1,344',
#        '₹1,972', '₹491', '₹250', '₹4,399', '₹299', '₹149', '₹599', '₹250',
#        '₹250', '₹125', '₹695', '₹250', '₹129', '₹249', '₹149', '₹299',
#        '₹299', '₹199', '₹199', '₹299', '₹199', '₹199', '₹275', '₹2,832',
#        '₹399', '₹299', '₹2,911', '₹799', '₹299', '₹399', '₹299', '₹3,450',
#        '₹699', '₹399', '₹499', '₹250', '₹250', '₹3,483', '₹299', '₹2,765',
#        '₹223', '₹599', '₹296', '₹299', '₹297', '₹1,680', '₹210', '₹399',
#        '₹349', '₹349', '₹249', '₹59', '₹189', '₹1,817', '₹275', '₹699',
#        '₹792', '₹550', '₹756', '₹499', '₹199', '₹545', '₹199', '₹410',
#        '₹248', '₹618', '₹899', '₹799', '₹399', '₹1,295', '₹250', '₹599',
# ...

# %%
#as we observe the above data it is not cleaned enough so again we are clean the above data to get better insights
df['MRP_clean'] = df['MRP'].str.extract(r'₹([\d,]+)')

# %%
df['MRP_clean'].values
# Out:
# array(['465', '749', '199', '149', '629', '699', '399', '299', '1,090',
#        '350', '250', '799', '949', '349', '1,558', '275', '499', '396',
#        '199', '258', '275', '990', '1,399', '399', '250', '349', '1,499',
#        '250', '125', '299', '403', '1,344', '1,972', '491', '250',
#        '4,399', '299', '149', '599', '250', '250', '125', '695', '250',
#        '129', '249', '149', '299', '299', '199', '199', '299', '199',
#        '199', '275', '2,832', '399', '299', '2,911', '799', '299', '399',
#        '299', '3,450', '699', '399', '499', '250', '250', '3,483', '299',
#        '2,765', '223', '599', '296', '299', '297', '1,680', '210', '399',
#        '349', '349', '249', '59', '189', '1,817', '275', '699', '792',
#        '550', '756', '499', '199', '545', '199', '410', '248', '618',
#        '899', '799', '399', '1,295', '250', '599', '250', '399', '190',
#        '599', '683', '299', '349', '149', '225', '299', '1,889', '594',
# ...

# %%
#Now we need convert this MRP_clean object data type to float/int data type because money is always measures in numbers
df['MRP_clean'] = df['MRP_clean'].str.replace(',', '')
df['MRP_clean']=df['MRP_clean'].astype(int)

# %%
df
# Out:
#                                              book name  \
# 0                             Lets Crack SSB Interview
# 1    My First Library: Boxset of 10 Board Books for...
# 2    Fruits - My First Early Learning Wall Chart: F...
# 3    My First Book of Patterns: Pencil Control: Pat...
# 4    Colouring Books Boxset: Pack of 12 Copy Colour...
# ..                                                 ...
# 396  Illustrated Stories of Akbar and Birbal: Class...
# 397  The Tale of a Naughty Prank: A Puffin Chapter ...
# 398  Majestic Animals: Colouring Books for Adults w...
# 399      Creative Coloring Mandala for Kids(Paperback)
# 400  MTG National Science Olympiad (NSO) Workbook f...
#
#                                                 Author  \
# 0                                             SSBCrack
# 1    Wonder House Books Editorial(Author),  Wonder ...
# 2                                   Wonder House Books
# 3    Wonder House Books Editorial(Author),  Wonder ...
# ...

# %%
df['MRP_clean'].isnull().sum()
# Out:
# 0

# %%
df['MRP_clean'].value_counts()
# Out:
# 299     32
# 199     24
# 399     24
# 250     21
# 499     19
#         ..
# 3235     1
# 220      1
# 1180     1
# 595      1
# 735      1
# Name: MRP_clean, Length: 165, dtype: int64

# %% [markdown]
# # Discount

# %%
#Replace '%' and convert to numeric
df['discount'] = df['discount'].str.replace('%', '').astype(float)
#Convert to decimal by dividing by 100
df['discount'] /= 100

# %%
df
# Out:
#                                              book name  \
# 0                             Lets Crack SSB Interview
# 1    My First Library: Boxset of 10 Board Books for...
# 2    Fruits - My First Early Learning Wall Chart: F...
# 3    My First Book of Patterns: Pencil Control: Pat...
# 4    Colouring Books Boxset: Pack of 12 Copy Colour...
# ..                                                 ...
# 396  Illustrated Stories of Akbar and Birbal: Class...
# 397  The Tale of a Naughty Prank: A Puffin Chapter ...
# 398  Majestic Animals: Colouring Books for Adults w...
# 399      Creative Coloring Mandala for Kids(Paperback)
# 400  MTG National Science Olympiad (NSO) Workbook f...
#
#                                                 Author  \
# 0                                             SSBCrack
# 1    Wonder House Books Editorial(Author),  Wonder ...
# 2                                   Wonder House Books
# 3    Wonder House Books Editorial(Author),  Wonder ...
# ...

# %% [markdown]
# # Save_upto

# %%
df['Save_upto']=df['Save_upto'].str.replace('₹', '')

# %%
df
# Out:
#                                              book name  \
# 0                             Lets Crack SSB Interview
# 1    My First Library: Boxset of 10 Board Books for...
# 2    Fruits - My First Early Learning Wall Chart: F...
# 3    My First Book of Patterns: Pencil Control: Pat...
# 4    Colouring Books Boxset: Pack of 12 Copy Colour...
# ..                                                 ...
# 396  Illustrated Stories of Akbar and Birbal: Class...
# 397  The Tale of a Naughty Prank: A Puffin Chapter ...
# 398  Majestic Animals: Colouring Books for Adults w...
# 399      Creative Coloring Mandala for Kids(Paperback)
# 400  MTG National Science Olympiad (NSO) Workbook f...
#
#                                                 Author  \
# 0                                             SSBCrack
# 1    Wonder House Books Editorial(Author),  Wonder ...
# 2                                   Wonder House Books
# 3    Wonder House Books Editorial(Author),  Wonder ...
# ...

# %% [markdown]
# # if we observe both discount and save_upto columns are inter linked
# - To fill the null values we can use both columns
# - If and only if the discount if not there then, there is no save_upto value
# - If the both columns having null values then we are replacing with 0 value

# %%
# Replace null values with 0 for both 'discount' and 'save_upto' if both are NaN
df.loc[df['discount'].isna() & df['Save_upto'].isna(), ['discount', 'Save_upto']] = 0

# %%
df
# Out:
#                                              book name  \
# 0                             Lets Crack SSB Interview
# 1    My First Library: Boxset of 10 Board Books for...
# 2    Fruits - My First Early Learning Wall Chart: F...
# 3    My First Book of Patterns: Pencil Control: Pat...
# 4    Colouring Books Boxset: Pack of 12 Copy Colour...
# ..                                                 ...
# 396  Illustrated Stories of Akbar and Birbal: Class...
# 397  The Tale of a Naughty Prank: A Puffin Chapter ...
# 398  Majestic Animals: Colouring Books for Adults w...
# 399      Creative Coloring Mandala for Kids(Paperback)
# 400  MTG National Science Olympiad (NSO) Workbook f...
#
#                                                 Author  \
# 0                                             SSBCrack
# 1    Wonder House Books Editorial(Author),  Wonder ...
# 2                                   Wonder House Books
# 3    Wonder House Books Editorial(Author),  Wonder ...
# ...

# %%
#checking if there any null values in discount and save_upto
df.isnull().sum()
# Out:
# book name       12
# Author          32
# category         0
# Released        20
# Rating         164
# MRP              0
# Save_upto        0
# discount         0
# No of pages     21
# returnable       0
# MRP_clean        0
# dtype: int64

# %% [markdown]
# - There is no null values in discount and Save_upto

# %%
df['Save_upto'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 401 entries, 0 to 400
# Series name: Save_upto
# Non-Null Count  Dtype
# --------------  -----
# 401 non-null    object
# dtypes: object(1)
# memory usage: 3.3+ KB

# %%
df['Save_upto'].values
# Out:
# array([0, '225', '80', '60', '182', '210', '96', '84', '283', '80', '45',
#        '120', '294', '80', 0, '66', '190', '95', '80', 0, '52', '337',
#        '490', '140', '45', '80', '480', '45', '50', '60', 0, '309', 0,
#        '157', '45', '1540', '60', '60', '174', '45', '45', '50', '174',
#        '45', '52', '42', '60', '60', '60', '80', '80', '60', '80', '14',
#        '52', 0, 0, '15', '786', '248', '60', '120', '60', '1000', '210',
#        '140', '190', '45', '45', 0, '60', 0, 0, '174', 0, '60', 0, '302',
#        '29', '96', '80', '80', '42', '24', '76', 0, '38', '210', '246',
#        '192', 0, '135', '80', '153', '80', 0, '42', 0, '279', '248',
#        '140', '453', '45', '234', '70', '96', '76', '174', 0, '60', '80',
#        '60', '34', '60', 0, '172', 0, '387', '135', '52', '210', 0, '248',
#        '80', '341', 0, '27', '60', '140', '143', '117', '80', '366', '55',
#        0, '80', '45', '96', '80', '77', '80', 0, '160', '30', '60', '91',
# ...

# %%
#changing the data type of save_upto to integer

# %%
df['Save_upto']=df['Save_upto'].astype(int)

# %%
df
# Out:
#                                              book name  \
# 0                             Lets Crack SSB Interview
# 1    My First Library: Boxset of 10 Board Books for...
# 2    Fruits - My First Early Learning Wall Chart: F...
# 3    My First Book of Patterns: Pencil Control: Pat...
# 4    Colouring Books Boxset: Pack of 12 Copy Colour...
# ..                                                 ...
# 396  Illustrated Stories of Akbar and Birbal: Class...
# 397  The Tale of a Naughty Prank: A Puffin Chapter ...
# 398  Majestic Animals: Colouring Books for Adults w...
# 399      Creative Coloring Mandala for Kids(Paperback)
# 400  MTG National Science Olympiad (NSO) Workbook f...
#
#                                                 Author  \
# 0                                             SSBCrack
# 1    Wonder House Books Editorial(Author),  Wonder ...
# 2                                   Wonder House Books
# 3    Wonder House Books Editorial(Author),  Wonder ...
# ...

# %% [markdown]
# # Released

# %%
df['Released'].values
# Out:
# array(['7 April 2017', '2018', '12 Oct 2020', '2018', '20 Jan 2019',
#        '01 Aug 2019', '10 Jun 2018', '24 Apr 2023', '15 Jul 2023',
#        '01 Aug 2021', '28 Feb 2022', '10-Apr-2022', '01 Aug 2019',
#        '2.07.2019', '15 Mar 2024', '5-5-21', '02 Aug 2016', '01 Sep 2020',
#        '2015', '13 May 2023', '01 Jan 2015', '20 Nov 2000', '25 Dec 2021',
#        '2005', nan, '01 Nov 2019', '01 Jan 2019', '26 Feb 2024',
#        '03 Mar 2016', '05 Sep 2018', '10 Mar 2024', '11 Aug 2009',
#        '05 Jun 2023', '01 Aug 2021', '31 Jan 2021', '04 Jul 2012',
#        '20 Jul 2018', '01 Jul 2020', '05 Apr 2022', '01 Apr 2017',
#        '14 July 2017', '01 Sep 2021', '2015', '01 Aug 2021', '20',
#        '05 Feb 2020', '31 Aug 2022', '15 Oct 2024', '25 Apr 2018',
#        '01 Oct 2014', '10 August 2017', '02', '27 Oct 2020',
#        '01 Jan 2020', '01 Jan 1900', '17 Feb 2024', '01 Jan 2021',
#        '31 Aug 2022', '28 Sep 2022', '25', '20 Jul 2018', '2018',
# ...

# %%
df['Released_year']=pd.to_datetime(df['Released'], errors='coerce').dt.year

# %%
df['Released_year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 401 entries, 0 to 400
# Series name: Released_year
# Non-Null Count  Dtype
# --------------  -----
# 376 non-null    float64
# dtypes: float64(1)
# memory usage: 3.3 KB

# %%
df['Released_year'].values
# Out:
# array([2017., 2018., 2020., 2018., 2019., 2019., 2018., 2023., 2023.,
#        2021., 2022., 2022., 2019., 2019., 2024., 2021., 2016., 2020.,
#        2015., 2023., 2015., 2000., 2021., 2005.,   nan, 2019., 2019.,
#        2024., 2016., 2018., 2024., 2009., 2023., 2021., 2021., 2012.,
#        2018., 2020., 2022., 2017., 2017., 2021., 2015., 2021.,   nan,
#        2020., 2022., 2024., 2018., 2014., 2017.,   nan, 2020., 2020.,
#        1900., 2024., 2021., 2022., 2022.,   nan, 2018., 2018., 2018.,
#        2020., 2022., 2007., 2019., 2023., 2019., 2010., 2008., 2024.,
#        2021., 2022., 2023., 2019., 2023., 2020., 2023.,   nan, 2017.,
#        2020., 2022., 2018.,   nan, 2024., 2011., 2015., 2024., 2016.,
#        2024., 2023.,   nan, 2017., 2019., 2016., 2020., 2024., 2021.,
#        2022., 2000., 2022., 2020., 2023., 2020., 2017., 2010., 2014.,
#        2023., 2018., 2021., 2021.,   nan, 2005., 2023., 2021., 2023.,
# ...

# %%
# df['Released_year']=df['Released_year'].fillna(0).astype(int)

# %%
df['Released_year'] = df.groupby('category')['Released_year'].apply(lambda x: x.fillna(x.median()))

# %%
df['Released_year']=df['Released_year'].astype(int)

# %%
df
# Out:
#                                              book name  \
# 0                             Lets Crack SSB Interview
# 1    My First Library: Boxset of 10 Board Books for...
# 2    Fruits - My First Early Learning Wall Chart: F...
# 3    My First Book of Patterns: Pencil Control: Pat...
# 4    Colouring Books Boxset: Pack of 12 Copy Colour...
# ..                                                 ...
# 396  Illustrated Stories of Akbar and Birbal: Class...
# 397  The Tale of a Naughty Prank: A Puffin Chapter ...
# 398  Majestic Animals: Colouring Books for Adults w...
# 399      Creative Coloring Mandala for Kids(Paperback)
# 400  MTG National Science Olympiad (NSO) Workbook f...
#
#                                                 Author  \
# 0                                             SSBCrack
# 1    Wonder House Books Editorial(Author),  Wonder ...
# 2                                   Wonder House Books
# 3    Wonder House Books Editorial(Author),  Wonder ...
# ...

# %%
df['Released_year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 401 entries, 0 to 400
# Series name: Released_year
# Non-Null Count  Dtype
# --------------  -----
# 401 non-null    int32
# dtypes: int32(1)
# memory usage: 1.7 KB

# %%
df.isnull().sum()
# Out:
# book name         12
# Author            32
# category           0
# Released          20
# Rating           164
# MRP                0
# Save_upto          0
# discount           0
# No of pages       21
# returnable         0
# MRP_clean          0
# Released_year      0
# dtype: int64

# %% [markdown]
# # Rating
# - replace null values with 0.0 in rating column

# %%
df['Rating'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 401 entries, 0 to 400
# Series name: Rating
# Non-Null Count  Dtype
# --------------  -----
# 237 non-null    float64
# dtypes: float64(1)
# memory usage: 3.3 KB

# %%
df['Rating'].values
# Out:
# array([4.7, 4.1, 4.5, 4.6, 4.5, 4.6, 4.4, 4.9, nan, 4.4, 4.6, nan, 4.5,
#        4.5, nan, nan, 4.4, 4.5, 4.2, nan, 4.7, 4.1, 4.8, 3.5, 4.4, 4.9,
#        nan, nan, nan, 4.5, nan, nan, nan, 4.7, 4.3, 4.7, 4.4, 4.4, 4.6,
#        4.3, 4.7, 4.1, nan, nan, 4.2, 4.7, 4.4, nan, nan, 4.5, 4.3, 4.5,
#        4.3, nan, nan, nan, 4.4, 4.7, nan, 4.5, 4.7, 4.7, 4.5, nan, nan,
#        4.9, 4.3, nan, 4.8, 4.8, nan, nan, 4.6, 3.8, nan, 4.5, nan, 4.5,
#        nan, nan, 4.2, nan, 4.9, 4.5, 4.5, nan, nan, 4.6, nan, 4.6, nan,
#        nan, 4.6, nan, 4.2, nan, 4.3, nan, 4.7, 4.6, nan, 4.9, 4.7, 4.5,
#        nan, 4.7, 4.1, 4.8, nan, 4.7, 4.8, 4.5, nan, 4.7, nan, 4.3, nan,
#        4.6, nan, 4.6, 4.9, nan, 4.2, 4.3, 4.2, nan, 4.6, nan, 4.7, 4.4,
#        4.3, 4.9, 4.4, nan, 4.9, 4.6, 4.4, nan, nan, nan, 4.2, nan, 4.7,
#        4.1, 4.7, 4.5, nan, 4.9, 4.5, 4.8, 4.6, 4.7, nan, 4.3, nan, nan,
#        4.5, 4.7, 4.5, nan, nan, 4.7, nan, 4.5, 4.6, nan, 4.9, nan, 3.8,
# ...

# %%
df['Rating']=df['Rating'].fillna('0.0')

# %%
df
# Out:
#                                              book name  \
# 0                             Lets Crack SSB Interview
# 1    My First Library: Boxset of 10 Board Books for...
# 2    Fruits - My First Early Learning Wall Chart: F...
# 3    My First Book of Patterns: Pencil Control: Pat...
# 4    Colouring Books Boxset: Pack of 12 Copy Colour...
# ..                                                 ...
# 396  Illustrated Stories of Akbar and Birbal: Class...
# 397  The Tale of a Naughty Prank: A Puffin Chapter ...
# 398  Majestic Animals: Colouring Books for Adults w...
# 399      Creative Coloring Mandala for Kids(Paperback)
# 400  MTG National Science Olympiad (NSO) Workbook f...
#
#                                                 Author  \
# 0                                             SSBCrack
# 1    Wonder House Books Editorial(Author),  Wonder ...
# 2                                   Wonder House Books
# 3    Wonder House Books Editorial(Author),  Wonder ...
# ...

# %%
df['Rating'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 401 entries, 0 to 400
# Series name: Rating
# Non-Null Count  Dtype
# --------------  -----
# 401 non-null    object
# dtypes: object(1)
# memory usage: 3.3+ KB

# %%
df['Rating']=df['Rating'].astype("float")

# %%
df.isnull().sum()
# Out:
# book name        12
# Author           32
# category          0
# Released         20
# Rating            0
# MRP               0
# Save_upto         0
# discount          0
# No of pages      21
# returnable        0
# MRP_clean         0
# Released_year     0
# dtype: int64

# %% [markdown]
# # Author
# - we can replace author name with Unknown

# %%
df['Author']=df['Author'].fillna("Unknown")

# %%
df['Author'].values
# Out:
# array(['SSBCrack',
#        'Wonder House Books Editorial(Author),  Wonder House Books ',
#        'Wonder House Books',
#        'Wonder House Books Editorial(Author),  Wonder House Books ',
#        'Wonder House Books(Author),  Wonder House Books ',
#        'Dale Carnegie, Napoleon Hill, Dr. Joseph Murphy & George S. Clason',
#        'Wonder House Books(Author),  Wonder House Books ', 'Unknown',
#        'M Laxmikanth', 'Maple Press ',
#        'Akshat Gupta(Author), Gupta, Akshat', 'R. S Aggarwal',
#        'Antoine de Saint-Exupéry, J.M. Barrie, Frances Hodgson Burnett & L. Frank Baum',
#        'Wonder House Books(Author),  Wonder House Books ',
#        'Mansi Sharma(Author), Educart(Author), Prashant Kirad(Author), Digraj Singh Rajput',
#        'Joseph Murphy(Author), Joseph Murphy', 'Colleen Hoover ',
#        'Morgan Housel',
#        'Dr Joseph Murphy(Author),  Joseph Murphy(Author), Joseph Murphy',
#        'Thibaut Meurisse',
# ...

# %%
df['Author'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 401 entries, 0 to 400
# Series name: Author
# Non-Null Count  Dtype
# --------------  -----
# 401 non-null    object
# dtypes: object(1)
# memory usage: 3.3+ KB

# %%
df.isnull().sum()
# Out:
# book name        12
# Author            0
# category          0
# Released         20
# Rating            0
# MRP               0
# Save_upto         0
# discount          0
# No of pages      21
# returnable        0
# MRP_clean         0
# Released_year     0
# dtype: int64

# %% [markdown]
# # book name

# %%
df['book name'].fillna('Unknown Book', inplace=True)

# %%
df.isnull().sum()
# Out:
# book name         0
# Author            0
# category          0
# Released         20
# Rating            0
# MRP               0
# Save_upto         0
# discount          0
# No of pages      21
# returnable        0
# MRP_clean         0
# Released_year     0
# dtype: int64

# %%
df['book name'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 401 entries, 0 to 400
# Series name: book name
# Non-Null Count  Dtype
# --------------  -----
# 401 non-null    object
# dtypes: object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# # No of pages

# %%
df['No of pages'].values
# Out:
# array([      nan, 2.200e+02, 1.000e+00, 4.800e+01, 1.920e+02, 9.600e+02,
#        6.400e+01, 1.680e+02, 8.400e+02, 1.600e+02, 2.560e+02,       nan,
#        9.360e+02, 8.400e+01, 1.230e+03, 2.340e+02, 3.840e+02, 2.520e+02,
#        2.560e+02, 8.000e+01, 1.920e+02, 4.800e+02, 1.456e+03, 1.920e+02,
#        2.980e+02, 4.240e+02, 4.400e+02, 2.560e+02, 1.280e+02, 9.600e+01,
#        3.180e+02, 3.680e+02, 2.950e+03, 2.560e+02, 2.400e+02, 5.264e+03,
#        2.400e+01, 2.320e+02, 3.360e+02, 2.240e+02, 2.560e+02, 4.800e+01,
#              nan, 2.880e+02, 1.000e+02, 3.200e+01, 4.800e+01, 4.000e+01,
#        6.400e+01, 1.920e+02, 2.280e+02, 1.120e+02, 2.560e+02, 1.320e+02,
#        1.640e+02, 1.688e+03, 2.600e+02, 2.600e+01, 1.200e+02, 6.400e+02,
#        2.400e+01, 3.360e+02, 6.400e+01, 3.360e+02, 1.600e+02, 3.520e+02,
#        3.840e+02, 1.760e+02, 2.560e+02, 1.328e+03, 1.600e+02, 2.176e+03,
#        3.760e+02, 1.920e+02, 1.600e+02, 9.600e+01, 1.600e+02, 1.600e+02,
# ...

# %%
# df['No of pages']=df['No of pages'].fillna(0).astype(int)
# Fill missing values in 'No of pages' based on the mean number of pages for each category
df['No of pages'] = df.groupby('category')['No of pages'].transform(lambda x: x.fillna(x.mean()))

# Convert the column to integers after filling the missing values
df['No of pages'] = df['No of pages'].astype(int)

# %%
df['No of pages'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 401 entries, 0 to 400
# Series name: No of pages
# Non-Null Count  Dtype
# --------------  -----
# 401 non-null    int32
# dtypes: int32(1)
# memory usage: 1.7 KB

# %%
df['Released'].fillna("Unknown",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   book name      401 non-null    object
#  1   Author         401 non-null    object
#  2   category       401 non-null    object
#  3   Released       401 non-null    object
#  4   Rating         401 non-null    float64
#  5   MRP            401 non-null    object
#  6   Save_upto      401 non-null    int32
#  7   discount       401 non-null    float64
#  8   No of pages    401 non-null    int32
#  9   returnable     401 non-null    object
#  10  MRP_clean      401 non-null    int32
#  11  Released_year  401 non-null    int32
# dtypes: float64(2), int32(4), object(6)
# memory usage: 31.5+ KB

# %%
df.isnull().sum()
# Out:
# book name        0
# Author           0
# category         0
# Released         0
# Rating           0
# MRP              0
# Save_upto        0
# discount         0
# No of pages      0
# returnable       0
# MRP_clean        0
# Released_year    0
# dtype: int64

# %% [markdown]
# # Handled missing values and changed datatypes

# %%
df
# Out:
#                                              book name  \
# 0                             Lets Crack SSB Interview
# 1    My First Library: Boxset of 10 Board Books for...
# 2    Fruits - My First Early Learning Wall Chart: F...
# 3    My First Book of Patterns: Pencil Control: Pat...
# 4    Colouring Books Boxset: Pack of 12 Copy Colour...
# ..                                                 ...
# 396  Illustrated Stories of Akbar and Birbal: Class...
# 397  The Tale of a Naughty Prank: A Puffin Chapter ...
# 398  Majestic Animals: Colouring Books for Adults w...
# 399      Creative Coloring Mandala for Kids(Paperback)
# 400  MTG National Science Olympiad (NSO) Workbook f...
#
#                                                 Author  \
# 0                                             SSBCrack
# 1    Wonder House Books Editorial(Author),  Wonder ...
# 2                                   Wonder House Books
# 3    Wonder House Books Editorial(Author),  Wonder ...
# ...

# %% [markdown]
# # Standardize text data
# - normalize the text columns for consistency

# %%
df['book name']=df['book name'].str.lower().str.strip()

# %%
df['Author']=df['Author'].str.lower().str.strip()

# %%
df['category']=df['category'].str.lower().str.strip()

# %%
df['Released']=df['Released'].str.lower().str.strip()

# %%
df['returnable']=df['returnable'].str.lower().str.strip()

# %%
df
# Out:
#                                              book name  \
# 0                             lets crack ssb interview
# 1    my first library: boxset of 10 board books for...
# 2    fruits - my first early learning wall chart: f...
# 3    my first book of patterns: pencil control: pat...
# 4    colouring books boxset: pack of 12 copy colour...
# ..                                                 ...
# 396  illustrated stories of akbar and birbal: class...
# 397  the tale of a naughty prank: a puffin chapter ...
# 398  majestic animals: colouring books for adults w...
# 399      creative coloring mandala for kids(paperback)
# 400  mtg national science olympiad (nso) workbook f...
#
#                                                 Author  \
# 0                                             ssbcrack
# 1    wonder house books editorial(author),  wonder ...
# 2                                   wonder house books
# 3    wonder house books editorial(author),  wonder ...
# ...

# %%
df.columns
# Out:
# Index(['book name', 'Author', 'category', 'Released', 'Rating', 'MRP',
#        'Save_upto', 'discount', 'No of pages', 'returnable', 'MRP_clean',
#        'Released_year'],
#       dtype='object')

# %% [markdown]
# # Checking for duplicates

# %%
df[df.duplicated(subset=['book name', 'Author', 'category', 'Released', 'Rating', 'MRP',
       'Save_upto', 'discount', 'No of pages', 'returnable', 'MRP_clean',
       'Released_year'])]
# Out:
# Empty DataFrame
# Columns: [book name, Author, category, Released, Rating, MRP, Save_upto, discount, No of pages, returnable, MRP_clean, Released_year]
# Index: []

# %%
df[df.duplicated(subset=['book name', 'Author', 'category', 'Released', 'Rating', 'MRP',
       'Save_upto', 'discount', 'No of pages', 'returnable'])]
# Out:
# Empty DataFrame
# Columns: [book name, Author, category, Released, Rating, MRP, Save_upto, discount, No of pages, returnable, MRP_clean, Released_year]
# Index: []

# %% [markdown]
# - The analysis reveals that there are no duplicate entries in the dataset, indicating a high level of data integrity. Each record appears to be unique, which is essential for accurate analysis and decision-making.

# %%
df
# Out:
#                                              book name  \
# 0                             lets crack ssb interview
# 1    my first library: boxset of 10 board books for...
# 2    fruits - my first early learning wall chart: f...
# 3    my first book of patterns: pencil control: pat...
# 4    colouring books boxset: pack of 12 copy colour...
# ..                                                 ...
# 396  illustrated stories of akbar and birbal: class...
# 397  the tale of a naughty prank: a puffin chapter ...
# 398  majestic animals: colouring books for adults w...
# 399      creative coloring mandala for kids(paperback)
# 400  mtg national science olympiad (nso) workbook f...
#
#                                                 Author  \
# 0                                             ssbcrack
# 1    wonder house books editorial(author),  wonder ...
# 2                                   wonder house books
# 3    wonder house books editorial(author),  wonder ...
# ...

# %%
df.columns
# Out:
# Index(['book name', 'Author', 'category', 'Released', 'Rating', 'MRP',
#        'Save_upto', 'discount', 'No of pages', 'returnable', 'MRP_clean',
#        'Released_year'],
#       dtype='object')

# %%
new_df = pd.DataFrame({
    "book name": df['book name'],
    "Author": df['Author'],
    "category": df['category'],
    "Released_year": df['Released_year'],
    "Rating": df['Rating'],
    "MRP": df['MRP_clean'],
    "Save_upto": df['Save_upto'],
    "discount": df['discount'],
    "No of pages": df['No of pages'],
    "returnable": df['returnable']
})

# %%
new_df
# Out:
#                                              book name  \
# 0                             lets crack ssb interview
# 1    my first library: boxset of 10 board books for...
# 2    fruits - my first early learning wall chart: f...
# 3    my first book of patterns: pencil control: pat...
# 4    colouring books boxset: pack of 12 copy colour...
# ..                                                 ...
# 396  illustrated stories of akbar and birbal: class...
# 397  the tale of a naughty prank: a puffin chapter ...
# 398  majestic animals: colouring books for adults w...
# 399      creative coloring mandala for kids(paperback)
# 400  mtg national science olympiad (nso) workbook f...
#
#                                                 Author  \
# 0                                             ssbcrack
# 1    wonder house books editorial(author),  wonder ...
# 2                                   wonder house books
# 3    wonder house books editorial(author),  wonder ...
# ...

# %%
new_df.columns
# Out:
# Index(['book name', 'Author', 'category', 'Released_year', 'Rating', 'MRP',
#        'Save_upto', 'discount', 'No of pages', 'returnable'],
#       dtype='object')

# %%
# Summary statistics for numerical columns
new_df.describe()
# Out:
#        Released_year      Rating           MRP    Save_upto    discount  \
# count     401.000000  401.000000    401.000000   401.000000  401.000000
# mean     2018.216958    2.665087    783.800499   143.763092    0.226384
# std        10.236958    2.230679   1100.329976   231.302716    0.134353
# min      1900.000000    0.000000     59.000000     0.000000    0.000000
# 25%      2018.000000    0.000000    250.000000    45.000000    0.150000
# 50%      2020.000000    4.300000    399.000000    80.000000    0.240000
# 75%      2022.000000    4.600000    787.000000   175.000000    0.330000
# max      2025.000000    4.900000  10332.000000  1980.000000    0.400000
#
#        No of pages
# count   401.000000
# mean    382.800499
# std     521.813477
# min       1.000000
# 25%     132.000000
# 50%     256.000000
# 75%     416.000000
# max    5264.000000

# %%
# Frequency counts for categorical columns
print(new_df['Author'].value_counts().sort_values(ascending=False))
# Out:
# unknown                                            32
# wonder house books                                 25
# wonder house books(author),  wonder house books    24
# maple press                                        10
# team pegasus                                        5
#                                                    ..
# poonam dalal dahiya                                 1
# fredrik backman(author), backman, fredrik           1
# holly jackson(author), jackson, holly               1
# issac pitman                                        1
# neelakantan, anand                                  1
# Name: Author, Length: 272, dtype: int64

# %% [markdown]
# ### Frequency Distribution of a Categorical columns

# %%
print(df['category'].value_counts())
print(len(df['category'].value_counts()))
# Out:
# general                          134
# children & teens                  81
# fiction                           52
# parenting, family & health        26
# exam central                      22
# society & social sciences         21
# history & humanities              19
# business & economics              13
# biographies & memoirs              7
# computer & internet                5
# lifestyle                          3
# dictionaries & language            3
# literature & literary studies      3
# english language teaching          3
# art & photography                  3
# references & encyclopedias         2
# science & mathematics              2
# technology & engineering           1
# medicine                           1
# Name: category, dtype: int64
# 19

# %%
category_counts =new_df['category'].value_counts()

# Create the pie chart
plt.figure(figsize=(10, 6))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Set2", len(category_counts)))

# Add title
plt.title('Distribution of Books by Category')

# Show the plot
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Create the vertical count plot
sns.countplot(x='category', data=new_df, palette="Set2", order=new_df['category'].value_counts().index)

# Rotate the category labels on the x-axis for better readability
plt.xticks(rotation=45, ha='right')

# Add title and labels
plt.title('Count of Books by Category')
plt.xlabel('Category')
plt.ylabel('Count')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight based on the category data:
# - There are **19** distinct book categories represented in the dataset.
# - Notably, the majority of bestselling books belong to the **general** category, highlighting its popularity among readers.

# %%
print(df['returnable'].value_counts())
# Out:
# y          204
# unknown    176
# n           21
# Name: returnable, dtype: int64

# %% [markdown]
# ### Insight based on returnable data
# - There are **204** books labeled as returnable, while **176** books are categorized as unknown regarding their returnability status. Additionally, **21** books are marked as non-returnable.
# - This indicates a substantial number of books that can be returned, but a significant portion remains uncertain about their return policy

# %% [markdown]
# ### Outliers detection

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#MRP column
sns.boxplot(x=new_df["MRP"])
plt.title(f'Box plot of MRP')
plt.show()

# %%
Q1 = new_df["MRP"].quantile(0.25)
Q3 = new_df["MRP"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print("lower_bound : ",lower_bound)
print("upper_bound : ",upper_bound)
outliers = new_df[(new_df["MRP"] < lower_bound) | (new_df["MRP"] > upper_bound)]
print(f"Outliers in {'MRP'}:")
outliers
# Out:
# lower_bound :  -555.5
# upper_bound :  1592.5
# Outliers in MRP:
#                                              book name  \
# 32   pw ncert punch physics, chemistry and biology ...
# 35          a game of thrones: the story continues(sc)
# 55   oswaal cbse question bank class 10 set of 4 bo...
# 58       rolex: special-edition wristwatches(hardback)
# 63   deportation machine: americas long history of ...
# 69                 mahabharata (3 vol. set)(hardbound)
# 71   educart cbse class 10 question bank 2024-25 sc...
# 77   101 tales: the great panchatantra collection: ...
# 85   51 trading strategies - optimise your trades w...
# 114  5000 + daily use english sentences | kanchan k...
# 116  physics galaxy set of 5 volumes for jee (main ...
# 134                        mahabharata (box set)(book)
# 141  financial statement analysis handbook - how to...
# 171                         rolex philosophy(hardback)
# 176  ncert exemplar problems-solutions mathematics ...
# ...

# %%
#Top 5 high cost books
#new_df[new_df["MRP"]>10000]
new_df.sort_values(by="MRP",ascending=False).head()
# Out:
#                                              book name  \
# 251        encyclopedia general science (e)(paperback)
# 242  ncert based general studies one liner 25000+(p...
# 218      knowledge encyclopedia: boxset of 8 books(sa)
# 171                         rolex philosophy(hardback)
# 176  ncert exemplar problems-solutions mathematics ...
#
#                                                 Author  \
# 251        experts arihant(author), siddharth mukherji
# 242  adhishree neurgaonkar(author), janmenjay sahan...
# 218                                            various
# 171                                   mara cappelletti
# 176  neha tyagi(author), amit rastogi (author),  am...
#
#                       category  Released_year  Rating    MRP  Save_upto  \
# 251  society & social sciences           2020     4.1  10332        413
# 242  society & social sciences           2022     0.0   6720        134
# 218           children & teens           2023     0.0   5999       1980
# ...

# %% [markdown]
# - Highest cost book in bestsellers is encyclopedia general science (e)(paperback)

# %%
#Rating
sns.boxplot(x=new_df["Rating"])
plt.title(f'Box plot of Rating')
plt.show()

# %% [markdown]
# - NO Outliers in Rating column

# %%
#Checking Value counts for Rating column
print(new_df["Rating"].value_counts().sort_values())
# Out:
# 3.5      1
# 3.4      1
# 3.2      1
# 3.6      1
# 3.8      2
# 3.9      5
# 4.2     11
# 4.1     13
# 4.9     23
# 4.3     24
# 4.8     26
# 4.4     27
# 4.6     29
# 4.7     35
# 4.5     38
# 0.0    164
# Name: Rating, dtype: int64

# %%
print(new_df["Rating"].value_counts().sort_index())
# Out:
# 0.0    164
# 3.2      1
# 3.4      1
# 3.5      1
# 3.6      1
# 3.8      2
# 3.9      5
# 4.1     13
# 4.2     11
# 4.3     24
# 4.4     27
# 4.5     38
# 4.6     29
# 4.7     35
# 4.8     26
# 4.9     23
# Name: Rating, dtype: int64

# %%
#Top 5 rating books 
new_df.sort_values(by="Rating",ascending=False).head()
# Out:
#                                              book name  \
# 200  relativity: the special and the general theory...
# 321  let talk money: youe worked hard for it, now m...
# 101                      the shiva trilogy(boxed pack)
# 65                    how to talk to anyone(paperback)
# 120   mahagatha: 100 tales from the puranas(paperback)
#
#                                        Author                    category  \
# 200  albert einstein(author), albert einstein        history & humanities
# 321                              monika halan                     general
# 101               amish tripathi (author), na                     fiction
# 65                               leil lowndes  parenting, family & health
# 120                satyarth nayak(author), na        history & humanities
#
#      Released_year  Rating   MRP  Save_upto  discount  No of pages returnable  \
# 200           2017     4.9   199         80      0.40          164          y
# ...

# %%
len(new_df[new_df['Rating']==4.9])
# Out:
# 23

# %% [markdown]
# ### Insight based on the Ratings data
# Based on the observed value counts, we can conclude the following:
#
# - **164 members** did not provide a rating.
# - The highest rating recorded is **4.9**, which was given by **23 members**.
# - The most frequently awarded rating is **4.5**, with **38 members** rating at this level.
#
# This indicates a significant number of members opted not to rate, while a strong preference exists for ratings around **4.5**.

# %%
filtered_df = new_df[new_df['Rating'] != 0]

# Create a subplot with 1 row and 2 columns
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Bar Plot on the first subplot (excluding 0 ratings)
sns.countplot(ax=axes[0], x='Rating', data=filtered_df)
axes[0].set_title('Bar Plot of Ratings')

# Histogram on the second subplot (excluding 0 ratings)
filtered_df['Rating'].plot(kind='hist', bins=10, ax=axes[1], edgecolor='black')
axes[1].set_title('Histogram of Ratings')
axes[1].set_xlabel('Rating')
plt.show()

# %%
#discount
sns.boxplot(x=new_df["discount"])
plt.title(f'Box plot of discount')
plt.show()

# %%
Q1 = new_df["discount"].quantile(0.25)
Q3 = new_df["discount"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print("lower_bound : ",lower_bound)
print("upper_bound : ",upper_bound)
outliers = new_df[(new_df["discount"] < lower_bound) | (new_df["discount"] > upper_bound)]
print(f"Outliers in {'discount'}:")
outliers
# Out:
# lower_bound :  -0.12000000000000002
# upper_bound :  0.6000000000000001
# Outliers in discount:
# Empty DataFrame
# Columns: [book name, Author, category, Released_year, Rating, MRP, Save_upto, discount, No of pages, returnable]
# Index: []

# %% [markdown]
# - NO Outliers in discount column

# %%
plt.scatter(new_df['discount'], new_df['MRP'])  # Assuming there's a 'Price' column
plt.title('Scatter Plot of Discounts vs. Price')
plt.xlabel('Discount (%)')
plt.ylabel('Price ($)')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Histogram on the first subplot (for continuous discounts)
sns.histplot(new_df['discount'], bins=10, ax=axes[0], edgecolor='black', kde=True)
axes[0].set_title('Distribution of Discounts with KDE')
axes[0].set_xlabel('Discount (%)')
axes[0].set_ylabel('Frequency')

# Bar Plot on the second subplot (for categorical discounts)
sns.countplot(ax=axes[1], y='discount', data=new_df)
axes[1].set_title('Count of Books by Discount Percentage')
axes[1].set_ylabel('Discount (%)')
axes[1].set_xlabel('Count of Books')
axes[1].tick_params(axis='x', rotation=90)
plt.show()

# %%
print(new_df['discount'].value_counts().sort_index())
# Out:
# 0.00    68
# 0.02     2
# 0.03     3
# 0.04     1
# 0.05     1
# 0.07     1
# 0.08     3
# 0.09     2
# 0.10     3
# 0.11     4
# 0.12     3
# 0.13     2
# 0.14     2
# 0.15     7
# 0.16     1
# 0.17    11
# 0.18    18
# 0.19     4
# 0.20    39
# 0.21     2
# 0.22     2
# 0.23    13
# 0.24    15
# 0.25     4
# 0.26     6
# 0.27    11
# 0.28     6
# 0.29    16
# 0.30    13
# 0.31    29
# 0.32     6
# 0.33     3
# 0.34     2
# 0.35    23
# 0.36     2
# 0.37     2
# 0.38     5
# 0.39     4
# 0.40    62
# Name: discount, dtype: int64
# 0.00    68
# 0.02     2
# 0.03     3
# 0.04     1
# 0.05     1
# 0.07     1
# 0.08     3
# 0.09     2
# 0.10     3
# 0.11     4
# 0.12     3
# 0.13     2
# 0.14     2
# 0.15     7
# 0.16     1
# 0.17    11
# 0.18    18
# 0.19     4
# 0.20    39
# 0.21     2
# 0.22     2
# 0.23    13
# 0.24    15
# 0.25     4
# 0.26     6
# 0.27    11
# 0.28     6
# 0.29    16
# 0.30    13
# 0.31    29
# 0.32     6
# 0.33     3
# 0.34     2
# 0.35    23
# 0.36     2
# ...

# %%
print(new_df['discount'].value_counts().sort_values())

# %%
new_df['discount'].mean()
# Out:
# 0.22638403990024983

# %% [markdown]
# ### Insight based on the discount data
# - The maximum discount offered is **40%**, which applies to *62* books. Additionally, *68* books do not have any discounts.
# - The average discount across all books is approximately **22%**.

# %%
#Released_year
sns.boxplot(x=new_df['Released_year'])
plt.title("Box plot of Released_year")
plt.show()

# %%
Q1 = new_df["Released_year"].quantile(0.25)
Q3 = new_df["Released_year"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print("lower_bound : ",lower_bound)
print("upper_bound : ",upper_bound)
outliers = new_df[(new_df["Released_year"] < lower_bound) | (new_df["Released_year"] > upper_bound)]
print(f"Outliers in Released_year:")
outliers
# Out:
# lower_bound :  2012.0
# upper_bound :  2028.0
# Outliers in Released_year:
#                                              book name  \
# 21                     the 48 laws of power(paperback)
# 23                                alchemist(paperback)
# 31   how to lose a war: more foolish plans and grea...
# 54                 magic of the lost temple(paperback)
# 65                    how to talk to anyone(paperback)
# 69                 mahabharata (3 vol. set)(hardbound)
# 70                  mans search for meaning(paperback)
# 86   oxford mini english dictionary | easy to use |...
# 100           where is babys belly button?(board book)
# 106                 autobiography of a yogi(paperback)
# 113  the monk who sold his ferrari: a fable about f...
# 132         original rider waite tarot deck(paperback)
# 166                      energize your mind(paperback)
# 169  certificate physical and human geography(paper...
# 184  tantric visions of the divine feminine(paperback)
# ...

# %%
new_df[(new_df["Released_year"] > upper_bound)]
# Out:
# Empty DataFrame
# Columns: [book name, Author, category, Released_year, Rating, MRP, Save_upto, discount, No of pages, returnable]
# Index: []

# %%
lower_bound_year=len(new_df[(new_df["Released_year"] < lower_bound)])
print(f"There are {lower_bound_year} Outilers in Released year")
# Out:
# There are 38 Outilers in Released year

# %%
new_df[new_df['Released_year']<1980]
# Out:
#                                book name  \
# 54   magic of the lost temple(paperback)
# 166        energize your mind(paperback)
#
#                                                 Author          category  \
# 54                   sudha murty(author),  sudha murty  children & teens
# 166  gaur gopal das(author), na(author), gaur gopa das           general
#
#      Released_year  Rating  MRP  Save_upto  discount  No of pages returnable
# 54            1900     0.0  275         52      0.19          164          y
# 166           1900     4.9  299         60      0.20          256    unknown

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Count Plot on the first subplot (for categorical counts of released_year)
sns.countplot(ax=axes[0], x='Released_year', data=new_df)
axes[0].set_title('Count of Books by Released Year')
axes[0].set_xlabel('Released Year')
axes[0].set_ylabel('Count of Books')
axes[0].tick_params(axis='x', rotation=90)  # Rotate x-axis labels for better readability

# Line Plot on the second subplot (for the trend of books released per year)
released_year_counts = new_df['Released_year'].value_counts().sort_index()
axes[1].plot(released_year_counts.index, released_year_counts.values, marker='.')
axes[1].set_title('Trend of Books Released Over the Years')
axes[1].set_xlabel('Released Year')
axes[1].set_ylabel('Number of Books Released')
axes[1].grid(True)

# %% [markdown]
# ### insight based on the Released year data
#
# - There are **38 outliers** in the `Released_year` column, but no upper-bound outliers were identified.
# - Notably, two older books, **"Magic of the Lost Temple" (Paperback)** and **"Energize Your Mind" (Paperback)**, are still bestsellers despite their age. This highlights their enduring popularity.
# - Most books were released in the years 2020 and 2023.

# %%
#No of pages  
sns.boxplot(x=new_df['No of pages'])
plt.title("Box plot of No of pages in a book")
plt.show()

# %%
Q1 = new_df["No of pages"].quantile(0.25)
Q3 = new_df["No of pages"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print("lower_bound : ",lower_bound)
print("upper_bound : ",upper_bound)
outliers = new_df[(new_df["No of pages"] < lower_bound) | (new_df["No of pages"] > upper_bound)]
print(f"Outliers in No of pages:")
print(len(outliers))
outliers
# Out:
# lower_bound :  -294.0
# upper_bound :  842.0
# Outliers in No of pages:
# 37
#                                              book name  \
# 5    world’s greatest books for personal growth & w...
# 11   quantitative aptitude for competitive examinat...
# 12   best of childrens classics (set of 5 books): p...
# 14   educart cbse class 10 one shot question bank 2...
# 22   a good girls guide to murder (box set of 3 boo...
# 32   pw ncert punch physics, chemistry and biology ...
# 35          a game of thrones: the story continues(sc)
# 55   oswaal cbse question bank class 10 set of 4 bo...
# 69                 mahabharata (3 vol. set)(hardbound)
# 71   educart cbse class 10 question bank 2024-25 sc...
# 97   ssc tcs pyqs english language chapterwise & ty...
# 98   worlds greatest classics (set of 4 books): set...
# 101                      the shiva trilogy(boxed pack)
# 108  ssc tcs pyqs reasoning chapterwise & typewise ...
# 116  physics galaxy set of 5 volumes for jee (main ...
# ...

# %%
#Create bins for the 'No of pages' for the count plot
df['Pages Category'] = pd.cut(new_df['No of pages'], 
                               bins=[0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000], 
                               labels=['0-100', '101-200', '201-300', '301-400', 
                                       '401-500', '501-600', '601-700', '701-800', 
                                       '801-900', '901-1000'])

# Create a figure with 1 row and 2 columns for the subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Count Plot on the first subplot
sns.countplot(ax=axes[0], y='Pages Category', data=df)
axes[0].set_title('Count of Books by Page Count Category')
axes[0].set_xlabel('Count of Books')
axes[0].set_ylabel('Page Count Range')

# Violin Plot on the second subplot
sns.violinplot(ax=axes[1], x='No of pages', data=df)
axes[1].set_title('Violin Plot of Number of Pages')
axes[1].set_xlabel('Number of Pages')
plt.show()

# %%
plt.figure(figsize=(10, 3))
new_df['No of pages'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of Number of Pages')
plt.xlabel('Number of Pages')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ### Insight based on the No of pages data:
#
# - There are **37** outliers in the number of pages data, all of which exceed the upper limit.
# - The bestseller books predominantly fall within the page count ranges of 0-100 and 201-300.
# - The histogram plot indicates that the majority of books have fewer than 1000 pages.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### category and returnable

# %%
# To explore relationships between categorical variables (e.g., Category, Author, and Returnable),
# we can create a contingency table

# %%
# Count of returnable vs non-returnable by category
# returnable_counts = new_df.groupby(['category', 'returnable']).size().unstack(fill_value=0)
# returnable_counts
# Cross-tabulation between Category and Returnable
category_returnable_ct = pd.crosstab(new_df['category'], new_df['returnable'])
category_returnable_ct
# Out:
# returnable                     n  unknown   y
# category
# art & photography              2        0   1
# biographies & memoirs          1        0   6
# business & economics           0        6   7
# children & teens               1        3  77
# computer & internet            0        3   2
# dictionaries & language        0        2   1
# english language teaching      0        2   1
# exam central                   0       22   0
# fiction                        1       12  39
# general                        3      111  20
# history & humanities           2        1  16
# lifestyle                      0        0   3
# literature & literary studies  0        0   3
# medicine                       0        1   0
# parenting, family & health     1        8  17
# references & encyclopedias     1        0   1
# science & mathematics          0        2   0
# society & social sciences      9        3   9
# technology & engineering       0        0   1

# %%
#Categorical(category) vs. Categorical(returnable)
plt.figure(figsize=(12, 6))
sns.countplot(data=new_df, x='category', hue='returnable')
plt.title('Count of Books by Category and Returnable Status')
plt.xlabel('Category')
plt.ylabel('Count of Books')
plt.xticks(rotation=45)
plt.legend(title='Returnable', labels=['Unknown', 'Yes','No'])
# plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight based on category and returnable columns
#
# - Books in the **Children** and **Teens** categories have a higher count of returnable items.
# - In the **General** category, a significant number of books have an unknown returnable status.

# %% [markdown]
# ### Category vs. Rating

# %%
category_rating_summary = new_df.groupby('category')['Rating'].agg(['mean', 'median', 'min', 'max']).reset_index()
print(category_rating_summary)
# Out:
#                          category      mean  median  min  max
# 0               art & photography  1.433333    0.00  0.0  4.3
# 1           biographies & memoirs  1.242857    0.00  0.0  4.6
# 2            business & economics  2.461538    3.90  0.0  4.9
# 3                children & teens  3.495062    4.50  0.0  4.9
# 4             computer & internet  1.840000    0.00  0.0  4.9
# 5         dictionaries & language  1.533333    0.00  0.0  4.6
# 6       english language teaching  3.033333    4.50  0.0  4.6
# 7                    exam central  0.000000    0.00  0.0  0.0
# 8                         fiction  3.038462    4.40  0.0  4.9
# 9                         general  2.682090    4.30  0.0  4.9
# 10           history & humanities  2.963158    4.50  0.0  4.9
# 11                      lifestyle  1.433333    0.00  0.0  4.3
# 12  literature & literary studies  1.400000    0.00  0.0  4.2
# 13                       medicine  0.000000    0.00  0.0  0.0
# ...

# %%
# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

# Box Plot
sns.boxplot(x='category', y='Rating', data=df, ax=axes[0])
axes[0].set_title('Rating Distribution by Category')
axes[0].set_xlabel('Category')
axes[0].set_ylabel('Rating')
axes[0].tick_params(axis='x', rotation=45)

# Bar Plot
sns.barplot(x='category', y='Rating', data=df, estimator='mean', ax=axes[1])
axes[1].set_title('Average Rating by Category')
axes[1].set_xlabel('Category')
axes[1].set_ylabel('Average Rating')
axes[1].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight based on category and rating data
#
# - The **Exam Central**, **Medicine**, and **Technology & Engineering** categories have no ratings.
# - The **References & Encyclopedias** category holds the highest average rating, with a score of 4.5.

# %% [markdown]
# ### Author and MRP

# %%
author_mrp_summary = new_df.groupby('Author')['MRP'].agg(['mean', 'median', 'min', 'max']).reset_index()
author_mrp_summary.sort_values(by='max', ascending=False)
# Out:
#                                                 Author     mean   median  \
# 87         experts arihant(author), siddharth mukherji  10332.0  10332.0
# 4    adhishree neurgaonkar(author), janmenjay sahan...   6720.0   6720.0
# 257                                            various   2055.0    999.0
# 164                                   mara cappelletti   5625.0   5625.0
# 182  neha tyagi(author), amit rastogi (author),  am...   5040.0   5040.0
# ..                                                 ...      ...      ...
# 119  ie irodov(author), i.e. irodov(author),  unkno...    130.0    130.0
# 190                   oscar wilde(author), oscar wilde    129.0    129.0
# 90                                         franz kafka    129.0    129.0
# 107                       h g wells(author), h g wells    129.0    129.0
# 217  ronald meyer(translated),  fyodor dostoyevsky(...    125.0    125.0
#
#        min    max
# 87   10332  10332
# 4     6720   6720
# 257    223   5999
# ...

# %% [markdown]
# - The experts Arihant and Siddharth Mukherji have the highest MRP among bestselling books.

# %%
# # Create subplots
# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

# # Box Plot
# sns.boxplot(x='Author', y='MRP', data=new_df, ax=axes[0])
# axes[0].set_title('MRP Distribution by Author')
# axes[0].set_xlabel('Author')
# axes[0].set_ylabel('Maximum Retail Price (MRP)')
# axes[0].tick_params(axis='x', rotation=45)

# # Bar Plot
# sns.barplot(x='Author', y='MRP', data=new_df, estimator='mean', ax=axes[1])
# axes[1].set_title('Average MRP by Author')
# axes[1].set_xlabel('Author')
# axes[1].set_ylabel('Average Maximum Retail Price (MRP)')
# axes[1].tick_params(axis='x', rotation=45)

# # Adjust layout
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Rating and MRP

# %%
#Correlation Analysis: Compute the correlation between Rating and MRP to understand whether there is a linear relationship between the two variables.
correlation = new_df['Rating'].corr(new_df['MRP'])
print(f'Correlation between Rating and MRP: {correlation}')
# Out:
# Correlation between Rating and MRP: -0.07852427553458832

# %%
#Highest rating with low cost
# Sort by Rating (Descending) and MRP (Ascending)
low_cost_high_rating = new_df.sort_values(by=['Rating', 'MRP'], ascending=[False, True])

# Select top N books (e.g., top 5)
top_books = low_cost_high_rating.head()

# Display the top low-cost, high-rated books
top_books
# Out:
#                                              book name  \
# 131  shiva sutras: ancient indian teachings of shiv...
# 200  relativity: the special and the general theory...
# 82   shlokas and mantras - activity book for kids: ...
# 7         dont believe everything you think(paperback)
# 166                      energize your mind(paperback)
#
#                                                 Author              category  \
# 131            ranjit chaudhri(author), ranjit chaudhr  history & humanities
# 200           albert einstein(author), albert einstein  history & humanities
# 82                      wonder house books(author), na      children & teens
# 7                                              unknown               fiction
# 166  gaur gopal das(author), na(author), gaur gopa das               general
#
#      Released_year  Rating  MRP  Save_upto  discount  No of pages returnable  \
# 131           2019     4.9  199         80      0.40          144          y
# ...

# %%
# Creating bins for MRP
filtered_data=new_df.copy()
filtered_data['MRP_bins'] = pd.cut(new_df['MRP'], bins=[0, 200, 400, 600, 800, 1000], labels=['0-200', '201-400', '401-600', '601-800', '801-1000'])

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

# 1. Scatter Plot
sns.scatterplot(x='MRP', y='Rating', data=filtered_data, ax=axes[0])
axes[0].set_title('Rating vs MRP')
axes[0].set_xlabel('Maximum Retail Price (MRP)')
axes[0].set_ylabel('Rating')

# 2. Trend Line Plot (Linear Regression)
sns.regplot(x='MRP', y='Rating', data=filtered_data, ax=axes[1], scatter_kws={'s': 50})
axes[1].set_title('Rating vs MRP with Trend Line')
axes[1].set_xlabel('Maximum Retail Price (MRP)')
axes[1].set_ylabel('Rating')

# 3. Box Plot for MRP Bins
sns.boxplot(x='MRP_bins', y='Rating', data=filtered_data, ax=axes[2])
axes[2].set_title('Rating Distribution across MRP Bins')
axes[2].set_xlabel('MRP Range')
axes[2].set_ylabel('Rating')

# Adjust the layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight based on the Rating and MRP
# - A negative correlation suggests that higher-priced books receive lower ratings.

# %% [markdown]
# ### Rating and No of Pages

# %%
#Correlation: First, calculate the correlation between Rating and Number of Pages to see if there's any linear relationship.
correlation = new_df['Rating'].corr(new_df['No of pages'])
print(f'Correlation between Rating and No of Pages: {correlation}')
# Out:
# Correlation between Rating and No of Pages: -0.025604404314732713

# %%
filtered_df=new_df.copy()
# Creating bins for No of pages
filtered_df['Pages_bins'] = pd.cut(new_df['No of pages'], bins=[0, 200, 400, 600, 800, 1000], labels=['0-200', '201-400', '401-600', '601-800', '801-1000'])

# Create a figure with subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

# 1. Scatter Plot
sns.scatterplot(x='No of pages', y='Rating', data=filtered_df, ax=axes[0])
axes[0].set_title('Rating vs No of Pages')
axes[0].set_xlabel('Number of Pages')
axes[0].set_ylabel('Rating')

# 2. Trend Line Plot (Linear Regression)
sns.regplot(x='No of pages', y='Rating', data=filtered_df, ax=axes[1], scatter_kws={'s': 50})
axes[1].set_title('Rating vs No of Pages with Trend Line')
axes[1].set_xlabel('Number of Pages')
axes[1].set_ylabel('Rating')

# 3. Box Plot for Pages Bins
sns.boxplot(x='Pages_bins', y='Rating', data=filtered_df, ax=axes[2])
axes[2].set_title('Rating Distribution across Page Ranges')
axes[2].set_xlabel('Page Range')
axes[2].set_ylabel('Rating')

# Adjust the layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight based on the Rating and No of Pages
# - A negative correlation suggests that longer books tend to have lower ratings.

# %%
new_df.head()
# Out:
#                                            book name  \
# 0                           lets crack ssb interview
# 1  my first library: boxset of 10 board books for...
# 2  fruits - my first early learning wall chart: f...
# 3  my first book of patterns: pencil control: pat...
# 4  colouring books boxset: pack of 12 copy colour...
#
#                                               Author                 category  \
# 0                                           ssbcrack                  general
# 1  wonder house books editorial(author),  wonder ...         children & teens
# 2                                 wonder house books                  general
# 3  wonder house books editorial(author),  wonder ...  dictionaries & language
# 4    wonder house books(author),  wonder house books         children & teens
#
#    Released_year  Rating  MRP  Save_upto  discount  No of pages returnable  \
# 0           2017     4.7  465          0      0.00          373    unknown
# ...

# %% [markdown]
# ### Released Year and Rating

# %%
# Group by Released year and aggregate Rating (e.g., mean, min, max)
rating_summary = new_df.groupby('Released_year')['Rating'].agg(['mean', 'min', 'max']).reset_index()

# Display the grouped DataFrame
rating_summary.sort_values(by='mean',ascending=False)
# Out:
#     Released_year      mean  min  max
# 14           2007  4.700000  4.4  4.9
# 1            1989  4.700000  4.7  4.7
# 9            2002  4.650000  4.6  4.7
# 17           2010  4.550000  4.1  4.8
# 20           2013  4.540000  4.3  4.8
# 19           2012  4.450000  4.2  4.7
# 5            1995  4.300000  4.3  4.3
# 22           2015  4.181818  0.0  4.9
# 3            1992  4.100000  4.1  4.1
# 12           2005  4.100000  3.5  4.7
# 10           2003  4.000000  3.6  4.4
# 26           2019  3.946667  0.0  4.9
# 11           2004  3.900000  3.9  3.9
# 24           2017  3.838462  0.0  4.9
# 21           2014  3.640000  0.0  4.8
# 28           2021  3.442553  0.0  4.9
# 27           2020  3.410909  0.0  4.9
# 25           2018  3.396875  0.0  4.9
# 23           2016  2.945455  0.0  4.9
# 29           2022  2.804348  0.0  4.9
# 0            1900  2.450000  0.0  4.9
# 7            1999  2.200000  0.0  4.4
# 18           2011  1.566667  0.0  4.7
# 15           2008  1.533333  0.0  4.6
# ...

# %%
plt.figure(figsize=(8, 5))
plt.plot(rating_summary['Released_year'], rating_summary['mean'], marker='o', color='b', label='Mean Rating')
plt.fill_between(rating_summary['Released_year'], rating_summary['min'], rating_summary['max'], color='skyblue', alpha=0.3)
plt.title('Average Rating Over Released Years')
plt.xlabel('Released Year')
plt.ylabel('Rating')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(new_df['Released_year'].astype(str), new_df['Rating'], color='skyblue')
plt.title('Book Ratings by Release Year')
plt.xlabel('Released Year')
plt.ylabel('Rating')
plt.ylim(0, 5)  # Assuming rating is out of 5
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# ### Insight based on the released_year and rating
# - In 2007, we observed the highest average rating based on the analysis conducted.

# %% [markdown]
# ### No of pages and MRP

# %%
# Create scatter plot
plt.figure(figsize=(10, 5))
plt.scatter(new_df['No of pages'], new_df['MRP'], color='orange', s=100)
plt.title('Relationship between No. of Pages and MRP')
plt.xlabel('No. of Pages')
plt.ylabel('MRP')
plt.grid(True)
plt.show()

# %%
# Calculate correlation
correlation = new_df['No of pages'].corr(new_df['MRP'])
print(f'Correlation coefficient between No. of Pages and MRP: {correlation}')
# Out:
# Correlation coefficient between No. of Pages and MRP: 0.41815652173221873

# %% [markdown]
# -  A positive correlation suggests that more no of pages books tend to have a higher costs

# %%
more_pages_high_rating = new_df.sort_values(by=['No of pages', 'MRP'], ascending=[False,False])

# Select top N books (e.g., top 5)
top_book = more_pages_high_rating.head()

top_book
# Out:
#                                              book name  \
# 35          a game of thrones: the story continues(sc)
# 134                        mahabharata (box set)(book)
# 32   pw ncert punch physics, chemistry and biology ...
# 349                                       unknown book
# 116  physics galaxy set of 5 volumes for jee (main ...
#
#                                                 Author              category  \
# 35   george r. r. martin(author), george r r martin...               fiction
# 134        bibek debroy(translated), bibek debroy (tr)  history & humanities
# 32   dr. manish raj (m.r. sir)(author), dr. vipin k...          exam central
# 349                                            unknown               general
# 116                                       ashish arora          exam central
#
#      Released_year  Rating   MRP  Save_upto  discount  No of pages returnable  \
# 35            2012     4.7  4399       1540      0.35         5264          y
# ...

# %% [markdown]
# ### MRP and returnable

# %%
# Summary statistics of MRP based on returnable status
returnable_stats = new_df.groupby('returnable')['MRP'].describe()
returnable_stats
# Out:
#             count         mean          std    min    25%    50%     75%  \
# returnable
# n            21.0  2333.666667  2716.404946  125.0  425.0  699.0  4284.0
# unknown     176.0   746.937500   847.183354   80.0  256.0  430.5   799.0
# y           204.0   656.058824   879.712669   59.0  249.0  349.0   699.0
#
#                 max
# returnable
# n           10332.0
# unknown      5040.0
# y            5999.0

# %%
# Bar plot for mean MRP by returnable status
mean_mrp_by_returnable = new_df.groupby('returnable')['MRP'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(x='returnable', y='MRP', data=mean_mrp_by_returnable)
plt.title('Average MRP by Returnable Status')
plt.xlabel('Returnable')
plt.ylabel('Average MRP')
plt.show()

# %% [markdown]
# - non returnable is having more mean compare to returnable

# %%
new_df.columns
# Out:
# Index(['book name', 'Author', 'category', 'Released_year', 'Rating', 'MRP',
#        'Save_upto', 'discount', 'No of pages', 'returnable', 'MRP_bins',
#        'Pages_bins'],
#       dtype='object')

# %% [markdown]
# # multivariate

# %%
# Correlation matrix
corr_matrix = new_df[['Rating', 'MRP', 'Save_upto', 'discount', 'No of pages']].corr()

# Visualizing the correlation matrix
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Features')
plt.show()
# This matrix will help identify which numerical variables are strongly related,
# e.g., how No of Pages correlates with MRP, Rating, or Discount.

# %%
# A pair plot allows us to visualize pairwise relationships in the dataset, 
# which is useful for detecting correlations and interactions:
# Pair plot for numerical variables
sns.pairplot(new_df[['Rating', 'MRP', 'Save_upto', 'discount', 'No of pages']])
plt.show()
# This will show scatter plots and histograms for the numerical variables, 
# helping to understand the relationships between variables like Rating, MRP, No of Pages, etc.

# %%
# Box plot comparing MRP by Returnable status
plt.figure(figsize=(10,6))
sns.boxplot(x='returnable', y='MRP', data=new_df)
plt.title('MRP by Returnable Status')
plt.show()

# %%
# Create a correlation matrix
corr_matrix = new_df[['MRP', 'discount', 'Save_upto']].corr()

# Visualize with a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap: MRP, Discount, Save Upto')
plt.show()

# %% [markdown]
# - If we observe that cost increases then discount and save upto decreased
# - Discount increases then Save upto to increases
# - Discounts and Save Upto values might impact MRP significantly.
